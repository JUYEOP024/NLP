# %%
def solution(s):
    result =[]
    result.append(s)
    count = 0
    for i in range(len(s)):
        result[:-1] = result[:i+1]
        if result in [] or ():
            count += 1
    
    
    return count
solution("[](){}")
# Out:
# 0

# %%
s="[](){}"
result =[]
result.append(s)
count = 0
for i in range(len(s)):
    result[:-1] = result[:i+1]
    if result in [] or ():
            count += 1

print(count)
# Out:
# 0
